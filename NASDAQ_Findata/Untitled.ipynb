# %%
from pandas_datareader import data
import matplotlib.pyplot as plt
import pandas as pd

# %%
ticker = ['AAPL']
start_date = '2019-01-02'
end_date = '2021-05-01'

teny_yield = data.get_data_fred('GS10')

teny_yield.plot()
plt.show() #what does this do?

# %%
import yfinance as yf

data = yf.download("SPY AAPL MSFT",start="2019-01-01",end="2021-05-01")
# Out:
# [*********************100%***********************]  3 of 3 completed
#             Adj Close                              Close              \
#                  AAPL        MSFT         SPY       AAPL        MSFT
# Date
# 2018-12-31  38.395920   98.813278  239.992966  39.435001  101.570000
# 2019-01-02  38.439735   98.375481  240.242630  39.480000  101.120003
# 2019-01-03  34.610851   94.756454  234.509766  35.547501   97.400002
# 2019-01-04  36.088364   99.163513  242.364868  37.064999  101.930000
# 2019-01-07  36.008041   99.289970  244.275818  36.982498  102.059998
# 2019-01-08  36.694466  100.009888  246.570862  37.687500  102.800003
# 2019-01-09  37.317600  101.439995  247.723206  38.327499  104.269997
# 2019-01-10  37.436874  100.788193  248.597061  38.450001  103.599998
# 2019-01-11  37.069317  100.009888  248.693115  38.072498  102.800003
# 2019-01-14  36.511906   99.280251  247.175873  37.500000  102.050003
#
# ...

# %%
data.head(10)['Adj Close']

df_adjustedclose = data['Adj Close']

df_adjustedclose.head(15)

df_adjustedclose.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_adjustedclose
# Out:
#                   AAPL        MSFT         SPY
# Date
# 2018-12-31   38.395920   98.813278  239.992966
# 2019-01-02   38.439735   98.375481  240.242630
# 2019-01-03   34.610851   94.756454  234.509766
# 2019-01-04   36.088364   99.163513  242.364868
# 2019-01-07   36.008041   99.289970  244.275818
# ...                ...         ...         ...
# 2021-04-26  134.491562  261.549988  417.609985
# 2021-04-27  134.162109  261.970001  417.519989
# 2021-04-28  133.353485  254.559998  417.399994
# 2021-04-29  133.253662  252.509995  420.059998
# 2021-04-30  131.237091  252.179993  417.299988
#
# [588 rows x 3 columns]
